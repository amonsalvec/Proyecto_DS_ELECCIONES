# %% [markdown]
# # 📊 **Proyecto final del módulo: Análisis de las elecciones de la Comunidad Valenciana en los años 2009, 2014 y 2019**
#
# ---
#
# ### 🧑‍💻 **Autores:** INTRODUCIR LOS NOMBRES Y APELLIDOS AQUÍ
# ### 📅 **Fecha:** 6 de junio de 2025
#
# ---
#
# 📄 **Resumen:** Este estudio presenta un análisis comparativo de los resultados electorales en la Comunidad Valenciana durante las elecciones europeas de los años 2009, 2014 y 2019, utilizando datos oficiales extraídos de la plataforma gubernamental datos.gob.es. El objetivo principal es construir un modelo robusto de entrada, tratamiento y salida de datos que permita interpretar el comportamiento electoral y anticipar posibles tendencias políticas de cara a futuras convocatorias, tanto a nivel europeo como local. El análisis incluye un proceso sistemático de limpieza, estadarización y visualización de datos
#
# 📄 **Abstract:** This study presents a comparative analysis of electoral results in the Valencian Community during the European elections of 2009, 2014, and 2019, using official data extracted from the governmental platform datos.gob.es. The primary objective is to build a robust data pipeline, from ingestion to processing and output, that enables the interpretation of electoral behavior and the anticipation of potential political trends ahead of future elections, both at the European and local levels. The analysis involves a systematic process of data cleaning, standardization, and visualization.
#
# 📄 **Laburpena:** Ikerketa honek 2009, 2014 eta 2019ko Europako hauteskundeetan Valentziako Erkidegoan izandako hauteskunde-emaitzen analisi konparatiboa aurkezten du, Gobernuko plataformatik datos.gob.es ateratako datu ofizialak erabiliz. Helburu nagusia da datuen sarrera, tratamendu eta irteera eredu sendo bat eraikitzea, hauteskunde-portaera interpretatzeko eta etorkizuneko deialdiei begira egon daitezkeen joera politikoak aurreratzeko, bai Europan, bai tokian-tokian. Analisiak garbiketa, estadarizazio eta datuen
#
# ---
#
# ### 🗂️ **Índice**
# 1. Introducción.
# 2. Objetivos.
# 3. Metodología.
# 4. Contexto.
# 5. Proceso de creación.
# 6. Limpieza y normalización.
# 7. Análisis exploratorio de los datos de las elecciones.
# 8. Visualizaciones.
# 9. Conclusiones.
# 10. Recomendaciones (o futuras líneas de investigación).
#
# ---
#
# ### 📊 **Índice de gráficos, tablas, figuras e imágenes**
# 1. Imagen 1. Mapa comarcal de la Comunitat Valenciana.
# 2. Tabla 1. Municipios de la Comunidad Valenciana distribuidos por comarcas.
# 3. Tabla 2. Partidos políticos de la Comunidad Valenciana (2009, 2014 y 2019).
# 4. Tabla 3. Pruebas de aleatoriedad.
#
# ---
# ### **1.🔍Introducción**
#
# Este trabajo se enmarca dentro del proyecto final de módulo del itinerario formativo en análisis de datos, en el que se integran y aplican las competencias adquiridas en tres roles fundamentales del ciclo de vida del dato: **Data Engineer, Data Scientist y Data Analyst**. El objetivo es demostrar la capacidad técnica para construir, procesar, analizar y comunicar conjuntos de datos complejos, orientados a resolver necesidades reales en un contexto profesional.
#
# Como caso de estudio, se ha seleccionado el análisis electoral de la Comunidad Valenciana en el marco de las elecciones europeas celebradas en los años 2009, 2014 y 2019. Para ello, se han empleado datos abiertos procedentes de la plataforma gubernamental datos.gob.es, seleccionando los ficheros relevantes para esta comunidad autónoma. La elección de este caso responde a una necesidad planteada por nuestro empleador: comprender el contexto político actual y anticipar posibles tendencias de cara a futuras elecciones tanto europeas como locales.
#
# Desde una perspectiva técnica, el análisis aborda las siguientes etapas:
#
# **Data Engineering**: Se ha desarrollado una arquitectura robusta de ingestión de datos, incluyendo tareas de web scraping, llamadas a APIs y uso de SQL, orientadas a la modelización y organización eficiente de los datos electorales históricos.
#
# **Data Science**: El conjunto de datos fue sometido a un proceso sistemático de limpieza, normalización y análisis exploratorio para identificar patrones de comportamiento electoral, posibles sesgos y correlaciones entre variables clave.
#
# **Data Analysis**: Finalmente, se han elaborado visualizaciones interactivas y resúmenes ejecutivos que permiten comunicar hallazgos de forma clara y eficaz a públicos no técnicos, apoyándonos en herramientas como Jupyter Notebook, Pandas, Plotly y plataformas de BI.
#
# ---
# ### **2.📝Objetivos**
#
# #### **2.1. Objetivo principal**
#
# Realizar un análisis exhaustivo de los resultados electorales en la Comunidad Valenciana durante los comicios europeos de 2009, 2014 y 2019, con el fin de comprender la evolución del contexto político regional y detectar posibles tendencias que puedan anticipar el comportamiento electoral en futuras elecciones, tanto europeas como locales.
#
# #### **2.2. Objetivos sencudarios**
#
#
# ---
# ### **3. Metodología**
#
# Primeramente, en cuanto al diseño del estudio, este se enmarca dentro de un enfoque cuantitativo, de carácter descriptivo-analítico, centrado en la construcción de un modelo robusto para la recogida, procesamiento y análisis de datos electorales. El objetivo es comprender el contexto político actual y anticipar posibles tendencias de cara a las elecciones europeas y locales. El diseño contempla tanto la recopilación de datos secundarios a partir de fuentes oficiales como el desarrollo de herramientas de visualización y análisis que permitan presentar las conclusiones de forma clara, rigurosa y comunicativa durante las exposiciones finales del módulo.
#
# En segundo lugar, en lo referente a la muestra; la población objeto del estudio está compuesta por el conjunto de votantes registrados en los distintos municipios de la Comunidad Valenciana, si bien el análisis se centrará en el comportamiento electoral agregado por comarca y municipio. La muestra incluirá los datos disponibles en fuentes oficiales como el portal datos.gob.es, así como otras plataformas públicas de datos electorales. Se incluirán series históricas relevantes, resultados de anteriores comicios, índices de participación y, en la medida de lo posible, variables sociodemográficas asociadas al comportamiento electoral.
#
# En último lugar, desde la perspectiva de la ética, dado que el estudio se basa en datos abiertos y de carácter público, no se prevén riesgos asociados a la privacidad o la confidencialidad de la información. No obstante, se respetarán en todo momento los principios éticos de integridad, transparencia y veracidad en la manipulación y presentación de los datos. Cualquier visualización, conclusión o inferencia será debidamente contextualizada y respaldada por las fuentes utilizadas, evitando cualquier tipo de sesgo o manipulación interesada de los resultados.
#
# ---
# ### **4. Contexto**
#
# #### **4.1. Territorios**
#
# La Comunidad Valenciana es una comunidad autónoma situada en la costa este de España, compuesta por tres provincias: **Alicante, Castellón y Valencia**. Estas provincias se subdividen a su vez en varias comarcas, que son agrupaciones territoriales con identidad histórica y socioeconómica, y cada comarca incluye numerosos municipios que conforman la base administrativa local.
#
# <h4 align="center">Imagen 1. Mapa comarcal de la Comunitat Valenciana.</h4>
#
# ![Gráfico de resultados](https://ccoo1.webs.upv.es/Mapa_comarcas/mapa-comarcas.gif)
#
# Fuente: Google.
#
# En la Imagen 1 se representan las diferentes comarcas del territorio valenciano, diferenciadas mediante la aplicación del teorema de los cuatro colores, que garantiza que no haya dos regiones adyacentes (es decir, que compartan frontera) con el mismo color. A continuación, en la tabla, se detallan los municipios que componen cada comarca de la Comunidad Valenciana.
#
# <h4 align="center">Tabla 1. Municipios de la Comunidad Valenciana distribuidos por comarcas.</h4>
#
# | Nº  | Comarca           | Municipios |
# |-----|-------------------|------------|
# | 01  | ELS PORTS         | Castellfort, Cinctorres, Forcall, Herbés, La Mata de Morella, Morella, Olocau del Rei, Palanques, Portell de Morella, Todolella, Vallibona, Villores y Zorita del Maestrazgo. |
# | 02  | L'ALT MAESTRAT    | Albocasser, Ares del Maestre, Benasal, Catí, Culla, Tirig, Torre Embesora, Vilafranca del Cid, Villar de Canes. |
# | 03  | EL BAIX MAESTRAT  | Alcala de Xivert, Benicarlo, Calig, Canet lo Roig, Castell de Cabres, Xert, La Jana, Peñiscola, Pobla de Benifassá, Rosell, Salsadella, Sant Jordi, San Mateu, San Rafael del Rio, Santa Magdalena de Polpis, Traiguera, Vinaros. |
# | 04  | L'ALCALATÉN            | Adzaneta, Alcora, Benafigos, Xodos, Costur, Figueroles, Les Useres, Lucena del Cid, Vistabella del Maestrat. |
# | 05  | LA PLANA ALTA          | Almassora, Benicasim, Benlloch, Borriol, Cabanes, Castelló de la Plana, Coves de Vinromá, Oropesa, Pobla Tornesa, Sarratella, Sierra Engarcerán, Torre d'en Domenec, Torreblanca, Vall d'Alba, Vilafames, Vilanova d'Alcolea. |
# | 06  | LA PLANA BAIXA         | Ahín, Alcudia de Veo, Alfondeguilla, Almenara, Alqueries, Artana, Betxi, Borriana, Xilxes, Eslida, La Llosa, Moncófar, Nules, Onda, Ribesalbes, Sueras, Tales, Vall d'Uxo, Vila-Real, Villavieja. |
# | 07  | ALT PALANCIA           | Algimia del Almonacid, Almedijar, Altura, Azuébar, Barracas, Begís, Benafer, Castellnovo, Caudiel, Gátova, Geldo, Higueras, Jérica, Matet, Navajas, Pavías, Pina de Montalgrao, Sacañet, Segorbe, Soneja, Sot de Ferrer, Teresa, Torás, El Toro, Vall d'Almonacid, Viver. |
# | 08  | ALT MILLARS            | Arañuel, Argelita, Ayodar, Castillo de Villamalefa, Cirat, Cortes de Arenoso, Espadilla, Fanzara, Fuente de la Reina, Fuentes de Ayodar, Ludiente, Montán, Montanejos, Puebla de Arenoso, Toga, Torralba del Pinar, Torrechiva, Vallat, Villahermosa del Río, Villamalur, Villanueva de Viver, Zucaina. |
# | 09  | RACÓ D'ADEMUZ          | Ademuz, Casas Altas, Casas Bajas, Castielfabib, Puebla de San Miguel, Torrebaja, Vallanca. |
# | 10  | LOS SERRANOS           | Alcublas, Alpuente, Andilla, Aras de Alpuente, Benagéber, Bugarra, Calles, Xelva, Chulilla, Domeño, Gestalgar, Higueruelas, Losa del Obispo, Pedralba, Sot de Xera, Titaguas, Tuéjar, Villar del Arzobispo, La Yesa. |
# Las elecciones europeas celebradas en los años 2009, 2014 y 2019 en la Comunidad Valenciana han contado con una amplia variedad de partidos y candidaturas, que reflejan la pluralidad política regional y nacional. Entre las fuerzas más relevantes a nivel autonómico y local destacan partidos valencianistas como el Bloc Nacionalista Valencià-Coalició per Europa (BLOC), Esquerra Unida del País Valencià (EUPV) o Esquerra Republicana del País Valencià - Els Verds (EdP-V), que defienden la identidad y el autogobierno valenciano.
#
# Por otra parte, los grandes partidos nacionales con presencia consolidada en la región, como el Partido Popular (PP) y el Partido Socialista Obrero Español (PSOE), han mantenido un fuerte peso electoral, enfrentándose a nuevas formaciones emergentes y a candidaturas con distintos perfiles ideológicos, desde la izquierda más alternativa hasta la derecha más conservadora o nacionalista.
#
# Asimismo, en los procesos electorales europeos se presentan también formaciones con propuestas específicas o ideologías minoritarias, como el Partido Antitaurino contra el Maltrato Animal (PACMA), Iniciativa Feminista (IF) o grupos de corte comunista y republicano, lo que incrementa la complejidad del mapa político valenciano. En la siguiente figura se puede observar los candidatos de las elecciones.
#
# <h4 align="center">Tabla 2. Partidos políticos de la Comunidad Valenciana(2009, 2014 y 2019).</h4>
#
# | Código | Partido / Candidatura                                            | Siglas         |
# |--------|-----------------------------------------------------------------|----------------|
# | 14     | Partit Republicà Català                                          | RC             |
# | 15     | Partido Comunista de los Pueblos de España                      | PCPE           |
# | 17     | Unión Progreso y Democracia                                      | UPyD           |
# | 18     | Alternativa Española                                             | AES            |
# | 19     | Falange Auténtica                                               | FA             |
# | 20     | Por un Mundo más Justo                                           | PUM+J          |
# | 22     | Salamanca-Zamora-León                                            | PREPAL         |
# | 23     | Centro Democrático y Social                                      | CDS            |
# | 24     | Libertas-Ciudadanos de España                                   | LIBERTAS       |
# | 26     | Frente Nacional                                                 | FN             |
# | 27     | Partido Antitaurino contra el Maltrato Animal                   | PACMA          |
# | 28     | Partido Socialista Obrero Español                                | PSOE           |
# | 29     | Movimiento Social Republicano                                   | MSR            |
# | 30     | Unidá Nacionalista Asturiana                                    | UNA            |
# | 32     | Democracia Nacional                                             | DN             |
# | 34     | Unificación Comunista de España                                | UCE            |
# | 35     | Partido Obrero Socialista Internacionalista                     | POSI           |
# | 36     | Andecha Astur                                                 | AA             |
# | 37     | Partido Humanista                                              | PH             |
# | 38     | Bloc Nacionalista Valencià-Coalició per Europa                  | BLOC           |
# | 39     | Esquerra Republicana del País Valencià- Els Verds               | EdP-V          |
# | 40     | Esquerra Anticapitalista-Revolta Global                         | IZAN-RG        |
# | 41     | Esquerra Unida del País Valencià: L'Esquerra                    | EUPV           |
# | 42     | Els Verds-Grup Verd Europeu-Los Verdes-Grupo Verde Europeo      | LV-GVE         |
# | 43     | Iniciativa Internacionalista - La Solidaritat entre els Pobles  | II             |
# | 1      | Iniciativa Feminista                                            | IF             |
# | 3      | Solidaridad y Autogestión Internacionalista                    | SAIn           |
# | 4      | Partido Socialista de Andalucía                                 | PSA            |
# | 5      | Falange Española de Las Jons                                   | FE de las JONS |
# | 8      | Partido Popular                                                | PP             |
# | 9      | Extremadura Unida                                             | EXTREMADURA UNIDA |
# | 10     | Centro Democrático Liberal                                    | CDL            |
# | 11     | Unió Valenciana                                              | UV             |
# | 12     | Partido Familia y Vida                                       | PFyV           |
# | 13     | Unión Centrista Liberal                                     | UCL            |
#
# Fuente: Creación propia.
#
# ---
# ### **5. Proceso de creación**
#
# #### **5.1. Data Engineering**
#
# #### **5.2. Data Scientist**
#
# #### **5.3. Data Analyst**
#
# ---
# ### **6. Limpieza y normalización**
#
# Con el fin de evaluar la representatividad y validez de los datos utilizados en este estudio, se han aplicado diversas pruebas estadísticas, técnicas de visualización y métodos de validación tanto interna como externa. El objetivo principal es detectar posibles sesgos derivados de un muestreo no aleatorio y asegurar que las conclusiones obtenidas sean fiables y generalizables.
#
# Las pruebas realizadas permiten examinar diferentes aspectos del conjunto de datos: la distribución de las variables, la independencia de las observaciones, la estabilidad de las estimaciones y la consistencia de los modelos predictivos. A continuación, se resume en forma de tabla el conjunto de pruebas aplicadas, sus resultados cuantitativos y la interpretación de los mismos en relación con la calidad y fiabilidad del muestreo.
#
# <h4 align="center">Tabla 3. Pruebas de aleatoriedad.</h4>
#
# | Prueba realizada | Resultado de la prueba | Interpretación |
# |------------------------------|-------------------------|----------------|
# | Test KS comparando con la distribución normal ('norm') | Estadístico KS: 0.1154<br>p-valor: 0.1288 | Los datos no difieren significativamente de una distribución normal. Se acepta la hipótesis de normalidad. |
# | Análisis de autocorrelación | Autocorrelación con lag 1: -0.1324 | La autocorrelación es baja y negativa, lo que sugiere independencia entre observaciones consecutivas. No hay evidencia de dependencia temporal. |
# | Prueba de corridas (runs test) usando la mediana como umbral | Número de corridas: 55<br>Número esperado: 51.0<br>Desviación estándar: 4.97<br>Estadístico Z: 0.8041 | Como el valor de Z está dentro del rango crítico (±1.96), no se rechaza la hipótesis de aleatoriedad. La secuencia puede considerarse aleatoria. |
# | Visualización de datos: Histogramas y Diagramas de Caja | Evaluación visual de la distribución: sin asimetrías pronunciadas ni outliers extremos | La forma de la distribución sugiere que no existen anomalías relevantes. Apoya la validez de la muestra. |
# | Validación Interna con Técnicas de Re-muestreo (Bootstrap) | Distribución amplia de la media bootstrap observada | Indica sensibilidad en la estimación de la media, lo que podría relacionarse con alta variabilidad en los datos o falta de representatividad en la muestra. |
# | Validación Externa: Cross-Validation con scikit-learn | Scores de validación cruzada: [0.8624, 0.9716, 0.9325, 0.9145, 0.9216]<br>Score promedio: 0.9205 | Score promedio alto y consistente. No se observa una variabilidad excesiva entre pliegues, lo que indica buena estabilidad del modelo y apoyo a la validez externa. |
#
# Fuente: Creación propia.
#
# ---
# ### **7. Análisis exploratorio de los datos de las elecciones**
#
# #### **7.1. Votos por provincia**
#
# #### **7.2. Votos por comarca**
#
# #### **7.3. Votos por partido político**
#
# #### **7.4. Votos por tendencia política**
# ---
# ### **8. Visualizaciones**
# ---
# ### **9. Conclusiones**
# ---
# ### **10. Recomendaciones (o futuras líneas de investigación)**
